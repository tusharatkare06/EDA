# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('whitegrid')

# %%
train_Data = pd.read_excel('Data_Train.xlsx')

# %%
train_Data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_Data = pd.read_excel('Test_set.xlsx')
test_Data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
# combine both data
data =[train_Data, test_Data]
final_data = pd.concat(data)

# %%
final_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
final_data['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0       24
# 1        1
# 2        9
# 3       12
# 4       01
#         ..
# 2666     6
# 2667    27
# 2668     6
# 2669     6
# 2670    15
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
# focus on date and time - derive feature from month and year

final_data['Date']= final_data['Date_of_Journey'].str.split('/').str[0]

# %%
final_data['Date_of_Journey'].str.split('/').str[1]
# Out:
# 0       03
# 1       05
# 2       06
# 3       05
# 4       03
#         ..
# 2666    06
# 2667    03
# 2668    03
# 2669    03
# 2670    06
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
final_data['Month']=final_data['Date_of_Journey'].str.split('/').str[1]
final_data['Year']=final_data['Date_of_Journey'].str.split('/').str[2]

# %%
final_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# ...

# %%
final_data= final_data.astype({"Date":'int', "Month":'int', "Year":'int'})

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %%
final_data.drop(['Date_of_Journey'], axis=1, inplace=True)

# %%
final_data.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info   Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info  3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info  7662.0     1      5
#
#    Year
# 0  2019
# 1  2019

# %%
final_data['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0       01:10
# 1       13:15
# 2       04:25
# 3       23:30
# 4       21:35
#         ...
# 2666    20:25
# 2667    16:55
# 2668    04:25
# 2669    19:15
# 2670    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_data.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time  Arrival_Time Duration  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20  01:10 22 Mar   2h 50m
#
#   Total_Stops Additional_Info   Price  Date  Month  Year
# 0    non-stop         No info  3897.0    24      3  2019

# %%
final_data['Arrival_Time']= final_data['Arrival_Time'].str.split(' ').str[0]

# %%
final_data.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time Arrival_Time Duration  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20        01:10   2h 50m
#
#   Total_Stops Additional_Info   Price  Date  Month  Year
# 0    non-stop         No info  3897.0    24      3  2019

# %%
final_data['Arrival_Time'].str.split(':').str[0]
# Out:
# 0       01
# 1       13
# 2       04
# 3       23
# 4       21
#         ..
# 2666    20
# 2667    16
# 2668    04
# 2669    19
# 2670    19
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_data['Arrival_Hr']= final_data['Arrival_Time'].str.split(':').str[0]

# %%
final_data['Arrival_Min']= final_data['Arrival_Time'].str.split(':').str[1]

# %%
final_data.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time Arrival_Time Duration  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20        01:10   2h 50m
#
#   Total_Stops Additional_Info   Price  Date  Month  Year Arrival_Hr  \
# 0    non-stop         No info  3897.0    24      3  2019         01
#
#   Arrival_Min
# 0          10

# %%
final_data.drop(['Arrival_Time'], axis =1, inplace= True)

# %%
final_data.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time Duration Total_Stops  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20   2h 50m    non-stop
#
#   Additional_Info   Price  Date  Month  Year Arrival_Hr Arrival_Min
# 0         No info  3897.0    24      3  2019         01          10

# %%
final_data= final_data.astype({"Arrival_Hr":'int', "Arrival_Min":'int'})

# %%
final_data.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time Duration Total_Stops  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20   2h 50m    non-stop
#
#   Additional_Info   Price  Date  Month  Year  Arrival_Hr  Arrival_Min
# 0         No info  3897.0    24      3  2019           1           10

# %%
final_data['Dep_Time']
# Out:
# 0       22:20
# 1       05:50
# 2       09:25
# 3       18:05
# 4       16:50
#         ...
# 2666    20:30
# 2667    14:20
# 2668    21:50
# 2669    04:00
# 2670    04:55
# Name: Dep_Time, Length: 13354, dtype: object

# %%
final_data['Dep_Hr']= final_data['Dep_Time'].str.split(':').str[0].astype(int)
final_data['Dep_Min']= final_data['Dep_Time'].str.split(':').str[1].astype(int)

# %%
final_data.drop(['Dep_Time'], axis =1, inplace= True)

# %%
final_data.head(1)
# Out:
#   Airline    Source Destination      Route Duration Total_Stops  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL   2h 50m    non-stop
#
#   Additional_Info   Price  Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  \
# 0         No info  3897.0    24      3  2019           1           10      22
#
#    Dep_Min
# 0       20

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_Hr       13354 non-null  int32
#  12  Arrival_Min      13354 non-null  int32
#  13  Dep_Hr           13354 non-null  int32
#  14  Dep_Min          13354 non-null  int32
# dtypes: float64(1), int32(7), object(7)
# memory usage: 1.3+ MB

# %%
final_data.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_Hr            0
# Arrival_Min           0
# Dep_Hr                0
# Dep_Min               0
# dtype: int64

# %%
final_data['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
final_data['Total_Stops']= final_data['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4,'nan':1})

# %%
final_data.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_Hr            0
# Arrival_Min           0
# Dep_Hr                0
# Dep_Min               0
# dtype: int64

# %%
final_data[final_data['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration  Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m          NaN
#
#      Additional_Info   Price  Date  Month  Year  Arrival_Hr  Arrival_Min  \
# 9039         No info  7480.0     6      5  2019           9           25
#
#       Dep_Hr  Dep_Min
# 9039       9       45

# %%
final_data = final_data.drop([final_data.index[9039]])

# %%
final_data.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 0
# Duration              0
# Total_Stops           0
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# Arrival_Hr            0
# Arrival_Min           0
# Dep_Hr                0
# Dep_Min               0
# dtype: int64

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13353 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13353 non-null  object
#  1   Source           13353 non-null  object
#  2   Destination      13353 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13353 non-null  object
#  5   Total_Stops      13353 non-null  float64
#  6   Additional_Info  13353 non-null  object
#  7   Price            10682 non-null  float64
#  8   Date             13353 non-null  int32
#  9   Month            13353 non-null  int32
#  10  Year             13353 non-null  int32
#  11  Arrival_Hr       13353 non-null  int32
#  12  Arrival_Min      13353 non-null  int32
#  13  Dep_Hr           13353 non-null  int32
#  14  Dep_Min          13353 non-null  int32
# dtypes: float64(2), int32(7), object(6)
# memory usage: 1.3+ MB

# %%
final_data.drop(['Route'], axis=1, inplace =True)

# %%
final_data.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min
# 0   3897.0    24      3  2019           1           10      22       20
# 1   7662.0     1      5  2019          13           15       5       50
# 2  13882.0     9      6  2019           4           25       9       25
# 3   6218.0    12      5  2019          23           30      18        5
# 4  13302.0     1      3  2019          21           35      16       50

# %%
final_data['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
final_data[final_data['Duration']=='5m']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          2.0         No info
# 2660  Air India  Mumbai   Hyderabad       5m          2.0         No info
#
#         Price  Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min
# 6474  17327.0     6      3  2019          16           55      16       50
# 2660      NaN    12      3  2019          16           55      16       50

# %%
final_data = final_data.drop([final_data.index[6474]])

# %%
final_data = final_data.drop([final_data.index[2660]])

# %%
final_data['Final_Duration']=final_data['Duration'].str.split(' ').str[0].str.split('h').str[0]. astype(int)

# %%
final_data.head(3)
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
#
#      Price  Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min  \
# 0   3897.0    24      3  2019           1           10      22       20
# 1   7662.0     1      5  2019          13           15       5       50
# 2  13882.0     9      6  2019           4           25       9       25
#
#    Final_Duration
# 0               2
# 1               7
# 2              19

# %%
final_data['Final_Duration_Min']=final_data['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
final_data.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min  \
# 0   3897.0    24      3  2019           1           10      22       20
# 1   7662.0     1      5  2019          13           15       5       50
# 2  13882.0     9      6  2019           4           25       9       25
# 3   6218.0    12      5  2019          23           30      18        5
# 4  13302.0     1      3  2019          21           35      16       50
#
#    Final_Duration Final_Duration_Min
# 0               2                 50
# ...

# %%
final_data['Final_Duration_Min']= final_data['Final_Duration_Min'].fillna(0)

# %%
final_data.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min  \
# 0   3897.0    24      3  2019           1           10      22       20
# 1   7662.0     1      5  2019          13           15       5       50
# 2  13882.0     9      6  2019           4           25       9       25
# 3   6218.0    12      5  2019          23           30      18        5
# 4  13302.0     1      3  2019          21           35      16       50
#
#    Final_Duration Final_Duration_Min
# 0               2                 50
# ...

# %%
final_data['Final_Duration_Min'] = final_data['Final_Duration_Min'].astype(int)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13350 entries, 0 to 2670
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Airline             13350 non-null  object
#  1   Source              13350 non-null  object
#  2   Destination         13350 non-null  object
#  3   Duration            13350 non-null  object
#  4   Total_Stops         13350 non-null  float64
#  5   Additional_Info     13350 non-null  object
#  6   Price               10680 non-null  float64
#  7   Date                13350 non-null  int32
#  8   Month               13350 non-null  int32
#  9   Year                13350 non-null  int32
#  10  Arrival_Hr          13350 non-null  int32
#  11  Arrival_Min         13350 non-null  int32
#  12  Dep_Hr              13350 non-null  int32
#  13  Dep_Min             13350 non-null  int32
#  14  Final_Duration      13350 non-null  int32
# ...

# %%
final_data['Total_Duration_in_Min']=final_data['Final_Duration']*60 +final_data['Final_Duration_Min']

# %%
final_data.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min  \
# 0   3897.0    24      3  2019           1           10      22       20
# 1   7662.0     1      5  2019          13           15       5       50
# 2  13882.0     9      6  2019           4           25       9       25
# 3   6218.0    12      5  2019          23           30      18        5
# 4  13302.0     1      3  2019          21           35      16       50
#
#    Final_Duration  Final_Duration_Min  Total_Duration_in_Min
# ...

# %%
final_data.drop(['Duration', 'Final_Duration','Final_Duration_Min'], axis=1, inplace=True)

# %%
final_data.head()
# Out:
#        Airline    Source Destination  Total_Stops Additional_Info    Price  \
# 0       IndiGo  Banglore   New Delhi          0.0         No info   3897.0
# 1    Air India   Kolkata    Banglore          2.0         No info   7662.0
# 2  Jet Airways     Delhi      Cochin          2.0         No info  13882.0
# 3       IndiGo   Kolkata    Banglore          1.0         No info   6218.0
# 4       IndiGo  Banglore   New Delhi          1.0         No info  13302.0
#
#    Date  Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min  \
# 0    24      3  2019           1           10      22       20
# 1     1      5  2019          13           15       5       50
# 2     9      6  2019           4           25       9       25
# 3    12      5  2019          23           30      18        5
# 4     1      3  2019          21           35      16       50
#
#    Total_Duration_in_Min
# 0                    170
# 1                    445
# 2                   1140
# 3                    325
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13350 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Airline                13350 non-null  object
#  1   Source                 13350 non-null  object
#  2   Destination            13350 non-null  object
#  3   Total_Stops            13350 non-null  float64
#  4   Additional_Info        13350 non-null  object
#  5   Price                  10680 non-null  float64
#  6   Date                   13350 non-null  int32
#  7   Month                  13350 non-null  int32
#  8   Year                   13350 non-null  int32
#  9   Arrival_Hr             13350 non-null  int32
#  10  Arrival_Min            13350 non-null  int32
#  11  Dep_Hr                 13350 non-null  int32
#  12  Dep_Min                13350 non-null  int32
#  13  Total_Duration_in_Min  13350 non-null  int32
# dtypes: float64(2), int32(8), object(4)
# ...

# %%
final_data['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencod = LabelEncoder()

# %%
final_data['Airline']= labelencod.fit_transform(final_data['Airline'])
final_data['Source']= labelencod.fit_transform(final_data['Source'])
final_data['Destination']= labelencod.fit_transform(final_data['Destination'])
final_data['Additional_Info']= labelencod.fit_transform(final_data['Additional_Info'])

# %%
final_data.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5          0.0                8   3897.0    24
# 1        1       3            0          2.0                8   7662.0     1
# 2        4       2            1          2.0                8  13882.0     9
# 3        3       3            0          1.0                8   6218.0    12
# 4        3       0            5          1.0                8  13302.0     1
#
#    Month  Year  Arrival_Hr  Arrival_Min  Dep_Hr  Dep_Min  \
# 0      3  2019           1           10      22       20
# 1      5  2019          13           15       5       50
# 2      6  2019           4           25       9       25
# 3      5  2019          23           30      18        5
# 4      3  2019          21           35      16       50
#
#    Total_Duration_in_Min
# 0                    170
# 1                    445
# 2                   1140
# 3                    325
# 4                    285

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13350 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Airline                13350 non-null  int32
#  1   Source                 13350 non-null  int32
#  2   Destination            13350 non-null  int32
#  3   Total_Stops            13350 non-null  float64
#  4   Additional_Info        13350 non-null  int32
#  5   Price                  10680 non-null  float64
#  6   Date                   13350 non-null  int32
#  7   Month                  13350 non-null  int32
#  8   Year                   13350 non-null  int32
#  9   Arrival_Hr             13350 non-null  int32
#  10  Arrival_Min            13350 non-null  int32
#  11  Dep_Hr                 13350 non-null  int32
#  12  Dep_Min                13350 non-null  int32
#  13  Total_Duration_in_Min  13350 non-null  int32
# dtypes: float64(2), int32(12)
# ...

# %%
final_data.isnull().sum()
# Out:
# Airline                     0
# Source                      0
# Destination                 0
# Total_Stops                 0
# Additional_Info             0
# Price                    2670
# Date                        0
# Month                       0
# Year                        0
# Arrival_Hr                  0
# Arrival_Min                 0
# Dep_Hr                      0
# Dep_Min                     0
# Total_Duration_in_Min       0
# dtype: int64
